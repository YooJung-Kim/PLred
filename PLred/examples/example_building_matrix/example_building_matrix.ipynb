# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from tqdm import tqdm

import PLred.fit as fit

# %%
model_file = '/Users/yjkim/Documents/PLred/PLred/examples/example_model_couplingmap/test_regulus.fits'
model_file2 = '/Users/yjkim/Documents/PLred/PLred/examples/example_model_couplingmap/regulus_20250211_polymodel_12:40:00_12:51:56.fits'

# %%
image_ngrid = 33 # 32
image_fov = 20 # mas
n_trim = 1

fitter = fit.PLMapFit(model_file = model_file, image_ngrid = image_ngrid, 
                      image_fov = image_fov, n_trim = n_trim)
# Out:
# loading model

# %%
fitter2 = fit.PLMapFit(model_file = model_file2, image_ngrid = image_ngrid, 
                      image_fov = image_fov, n_trim = n_trim)
# Out:
# loading model

# %%
specind = 90

fibinds = np.arange(38) #np.arange(38) # np.arange(25,30) #

fitter.make_matrix(specind, fibinds)
# Out:
# 1089it [00:21, 50.91it/s]
# all the fiber indices are used. saving the matrix to mat_full

# %%
fitter2.make_matrix(specind, fibinds)
# Out:
# 1089it [00:21, 50.86it/s]
# all the fiber indices are used. saving the matrix to mat_full

# %%
np.shape(fitter.mat)
# Out:
# (1089, 6422)

# %%
fibind = 0
plt.imshow(fitter.mat[1089//2,169*fibind:169*(fibind+1)].reshape((13,13)),vmin=0,vmax=0.015)

# %%
plt.imshow(fitter2.mat[1089//2,169*fibind:169*(fibind+1)].reshape((13,13)),vmin=0,vmax=0.015)

# %%
plt.imshow((fitter.mat - fitter2.mat)[1089//2,169*fibind:169*(fibind+1)].reshape((13,13)))
plt.colorbar()
